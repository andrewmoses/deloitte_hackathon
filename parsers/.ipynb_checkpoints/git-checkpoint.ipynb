# %%
f = open('../inputs/git.out','r', encoding='utf-8')
raw = f.read()
line_blocks = raw.split("\n\n")
line_blocks
# Out:
# ['\t Melih Değiş <melihdegis@gmail.com>:\n\t  insertions:    8 (0%)\n\t  deletions:     8 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 16\n\t  first commit:  Tue Jan 17 17:36:32 2017 +0300\n\t  last commit:   Tue Jan 17 17:36:32 2017 +0300',
#  '\t Phạm Ngọc Thắng <thangdc94@gmail.com>:\n\t  insertions:    2 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 3\n\t  first commit:  Wed Sep 19 10:17:16 2018 +0700\n\t  last commit:   Wed Sep 19 10:17:16 2018 +0700',
#  '\t Lukas Mestan <lukas.mestan@hyperia.sk>:\n\t  insertions:    88 (2%)\n\t  deletions:     51 (2%)\n\t  files:         7 (3%)\n\t  commits:       7 (3%)\n\t  lines changed: 139\n\t  first commit:  Mon Feb 6 08:57:05 2017 +0100\n\t  last commit:   Tue Sep 5 08:42:41 2017 +0200',
#  '\t Alef Farah <afarah@nelogica.com.br>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Wed Jul 25 18:32:15 2018 -0300\n\t  last commit:   Wed Jul 25 18:32:15 2018 -0300',
#  '\t Kevin Kuehler <keur@ocf.berkeley.edu>:\n\t  insertions:    9 (0%)\n\t  deletions:     6 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 15\n\t  first commit:  Sun Aug 11 13:59:33 2019 -0700\n\t  last commit:   Sun Aug 11 13:59:33 2019 -0700',
#  '\t Lukas Mestan <lukas.mestan@gmail.com>:\n\t  insertions:    2129 (54%)\n\t  deletions:     1007 (43%)\n\t  files:         120 (56%)\n\t  commits:       135 (64%)\n\t  lines changed: 3136\n\t  first commit:  Sun Jan 15 18:11:22 2017 +0100\n\t  last commit:   Tue Feb 18 11:31:35 2020 +0100',
#  '\t motiprajapati <prajapati.moti@gmail.com>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Fri Nov 30 13:26:17 2018 +0530\n\t  last commit:   Fri Nov 30 13:26:17 2018 +0530',
#  '\t Robert Beilich <robert@beilich.de>:\n\t  insertions:    3 (0%)\n\t  deletions:     3 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 6\n\t  first commit:  Tue Jul 17 09:36:12 2018 +0200\n\t  last commit:   Tue Jul 17 09:36:12 2018 +0200',
#  '\t Dan Kalowsky <dank@deadmime.org>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Wed Aug 22 14:37:11 2018 -0700\n\t  last commit:   Wed Aug 22 14:37:11 2018 -0700',
#  '\t Jorge Maldonado Ventura <jorgesumle@freakspot.net>:\n\t  insertions:    3 (0%)\n\t  deletions:     3 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 6\n\t  first commit:  Wed Sep 18 11:18:50 2019 +0200\n\t  last commit:   Wed Sep 18 11:18:50 2019 +0200',
#  '\t Jess <jessachandler@gmail.com>:\n\t  insertions:    31 (1%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 32\n\t  first commit:  Sat Mar 2 10:12:36 2019 -0800\n\t  last commit:   Sat Mar 2 10:12:36 2019 -0800',
#  '\t Ben Boeckel <mathstuf@gmail.com>:\n\t  insertions:    2 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 3\n\t  first commit:  Thu Sep 20 13:34:18 2018 -0400\n\t  last commit:   Thu Sep 20 13:34:18 2018 -0400',
#  '\t a7r3 <arvindultimate7352@gmail.com>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Thu Oct 19 22:04:33 2017 +0530\n\t  last commit:   Thu Oct 19 22:04:33 2017 +0530',
#  '\t Joshua de Guzman <devjoshuadeguzman@gmail.com>:\n\t  insertions:    27 (1%)\n\t  deletions:     16 (1%)\n\t  files:         5 (2%)\n\t  commits:       4 (2%)\n\t  lines changed: 43\n\t  first commit:  Fri May 10 00:24:16 2019 +0800\n\t  last commit:   Fri May 10 23:59:12 2019 +0800',
#  '\t Linell <tlbonnette@gmail.com>:\n\t  insertions:    7 (0%)\n\t  deletions:     7 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 14\n\t  first commit:  Mon Jan 16 20:57:20 2017 -0600\n\t  last commit:   Mon Jan 16 20:57:20 2017 -0600',
#  '\t Jérémy WALTHER <jeremy.walther@golflima.net>:\n\t  insertions:    34 (1%)\n\t  deletions:     0 (0%)\n\t  files:         2 (1%)\n\t  commits:       1 (0%)\n\t  lines changed: 34\n\t  first commit:  Thu Dec 12 19:09:56 2019 +0100\n\t  last commit:   Thu Dec 12 19:09:56 2019 +0100',
#  '\t Matt Hickman <mhickman@squareup.com>:\n\t  insertions:    4 (0%)\n\t  deletions:     4 (0%)\n\t  files:         3 (1%)\n\t  commits:       1 (0%)\n\t  lines changed: 8\n\t  first commit:  Thu May 16 14:51:38 2019 -0700\n\t  last commit:   Thu May 16 14:51:38 2019 -0700',
#  '\t Tom Ice <tomice@users.noreply.github.com>:\n\t  insertions:    7 (0%)\n\t  deletions:     6 (0%)\n\t  files:         2 (1%)\n\t  commits:       6 (3%)\n\t  lines changed: 13\n\t  first commit:  Fri May 10 12:48:55 2019 -0400\n\t  last commit:   Sun May 26 10:27:58 2019 -0400',
#  '\t Raimon Grau <raimonster@gmail.com>:\n\t  insertions:    7 (0%)\n\t  deletions:     0 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 7\n\t  first commit:  Tue Jan 17 14:36:22 2017 +0100\n\t  last commit:   Tue Jan 17 14:36:22 2017 +0100',
#  '\t Nicholas Skinsacos <nskins@umich.edu>:\n\t  insertions:    25 (1%)\n\t  deletions:     22 (1%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 47\n\t  first commit:  Thu Jan 19 00:34:53 2017 -0500\n\t  last commit:   Thu Jan 19 00:34:53 2017 -0500',
#  '\t mixn <sutanovac.milos@gmail.com>:\n\t  insertions:    9 (0%)\n\t  deletions:     9 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 18\n\t  first commit:  Thu Sep 27 13:56:19 2018 +0200\n\t  last commit:   Thu Sep 27 13:56:19 2018 +0200',
#  '\t Tom Ice <contact@thomasice.com>:\n\t  insertions:    1302 (33%)\n\t  deletions:     1025 (43%)\n\t  files:         33 (15%)\n\t  commits:       16 (8%)\n\t  lines changed: 2327\n\t  first commit:  Fri Dec 21 12:05:53 2018 -0500\n\t  last commit:   Tue Feb 11 08:25:44 2020 -0500',
#  '\t Chandra Prakash <chandra.pr.158@gmail.com>:\n\t  insertions:    22 (1%)\n\t  deletions:     8 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 30\n\t  first commit:  Sun Oct 13 02:16:54 2019 +0800\n\t  last commit:   Sun Oct 13 02:16:54 2019 +0800',
#  '\t Andrew Huss <git@ahuss.com>:\n\t  insertions:    3 (0%)\n\t  deletions:     0 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 3\n\t  first commit:  Sat Jan 28 15:53:55 2017 -0800\n\t  last commit:   Sat Jan 28 15:53:55 2017 -0800',
#  '\t Laurence <liuxy6@gmail.com>:\n\t  insertions:    3 (0%)\n\t  deletions:     3 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 6\n\t  first commit:  Mon Feb 18 19:58:26 2019 -0500\n\t  last commit:   Mon Feb 18 19:58:26 2019 -0500',
#  '\t Hugo Locurcio <hugo.locurcio@hugo.pro>:\n\t  insertions:    21 (1%)\n\t  deletions:     21 (1%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 42\n\t  first commit:  Thu Apr 11 14:35:17 2019 +0200\n\t  last commit:   Thu Apr 11 14:35:17 2019 +0200',
#  '\t Daniel <danieltaub7@gmail.com>:\n\t  insertions:    3 (0%)\n\t  deletions:     2 (0%)\n\t  files:         2 (1%)\n\t  commits:       2 (1%)\n\t  lines changed: 5\n\t  first commit:  Mon Nov 5 20:40:13 2018 +0200\n\t  last commit:   Mon Nov 5 20:45:01 2018 +0200',
#  '\t Andrej <andrej@gmail.com>:\n\t  insertions:    8 (0%)\n\t  deletions:     16 (1%)\n\t  files:         2 (1%)\n\t  commits:       2 (1%)\n\t  lines changed: 24\n\t  first commit:  Fri Oct 25 10:41:05 2019 +0200\n\t  last commit:   Fri Oct 25 14:23:15 2019 +0200',
#  '\t Miodrag Tokić <dev@loonies.io>:\n\t  insertions:    15 (0%)\n\t  deletions:     18 (1%)\n\t  files:         7 (3%)\n\t  commits:       7 (3%)\n\t  lines changed: 33\n\t  first commit:  Sun Feb 3 17:44:18 2019 +0100\n\t  last commit:   Mon Feb 4 12:42:21 2019 +0100',
#  '\t jdeguzman <jdeguzman@freelancer.com>:\n\t  insertions:    143 (4%)\n\t  deletions:     110 (5%)\n\t  files:         6 (3%)\n\t  commits:       6 (3%)\n\t  lines changed: 253\n\t  first commit:  Thu May 9 19:41:47 2019 +0800\n\t  last commit:   Fri May 10 18:57:04 2019 +0800',
#  '\t Dustin Blomquist <dustin.blomquist@gmail.com>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Sat Feb 18 01:08:10 2017 -0600\n\t  last commit:   Sat Feb 18 01:08:10 2017 -0600',
#  '\t Joopmicroop <Joopmicroop@gmail.com>:\n\t  insertions:    28 (1%)\n\t  deletions:     10 (0%)\n\t  files:         2 (1%)\n\t  commits:       1 (0%)\n\t  lines changed: 38\n\t  first commit:  Thu Jan 19 21:35:00 2017 +0100\n\t  last commit:   Thu Jan 19 21:35:00 2017 +0100',
#  '\t Joopmicroop <joopmicroop@gmail.com>:\n\t  insertions:    1 (0%)\n\t  deletions:     1 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 2\n\t  first commit:  Thu Jan 19 21:59:46 2017 +0100\n\t  last commit:   Thu Jan 19 21:59:46 2017 +0100',
#  '\t Brian Kroth <bpkroth@gmail.com>:\n\t  insertions:    23 (1%)\n\t  deletions:     4 (0%)\n\t  files:         1 (0%)\n\t  commits:       1 (0%)\n\t  lines changed: 27\n\t  first commit:  Fri Mar 17 10:53:25 2017 -0500\n\t  last commit:   Fri Mar 17 10:53:25 2017 -0500',
#  '\ttotal:\n\t  insertions:    3972 (100%)\n\t  deletions:     2368 (100%)\n\t  files:         213 (100%)\n\t  commits:       210 (100%)',
#  '']

# %%
name = []
email = []
c_lines = []
for each in line_blocks[:-2]:
    chunk = each.strip()
    b_ch = chunk.split("\n")
    a_line = b_ch[0].strip()
    a_l_list = a_line.split("<")
    print('name: ',a_l_list[0].strip())
    name.append(a_l_list[0].strip())
    emailpart = a_l_list[1].strip()
    emailalone = emailpart.replace('>:','')
    print('email: ',emailalone)
    email.append(emailalone)
    
#     print("author: ", )
    f_line = b_ch[5].strip()
    f_lines_list = f_line.split(" ")
#     print(f_lines_list)
    print("number of lines: ", f_lines_list[2].strip())
    c_lines.append(f_lines_list[2].strip())
    
    print("\n")
# Out:
# name:  Melih Değiş
# email:  melihdegis@gmail.com
# number of lines:  16
#
#
# name:  Phạm Ngọc Thắng
# email:  thangdc94@gmail.com
# number of lines:  3
#
#
# name:  Lukas Mestan
# email:  lukas.mestan@hyperia.sk
# number of lines:  139
#
#
# name:  Alef Farah
# email:  afarah@nelogica.com.br
# number of lines:  2
#
#
# name:  Kevin Kuehler
# email:  keur@ocf.berkeley.edu
# number of lines:  15
#
#
# name:  Lukas Mestan
# email:  lukas.mestan@gmail.com
# number of lines:  3136
#
#
# name:  motiprajapati
# email:  prajapati.moti@gmail.com
# number of lines:  2
#
#
# name:  Robert Beilich
# email:  robert@beilich.de
# number of lines:  6
#
#
# name:  Dan Kalowsky
# email:  dank@deadmime.org
# number of lines:  2
#
#
# name:  Jorge Maldonado Ventura
# email:  jorgesumle@freakspot.net
# number of lines:  6
#
#
# name:  Jess
# email:  jessachandler@gmail.com
# number of lines:  32
#
#
# name:  Ben Boeckel
# email:  mathstuf@gmail.com
# number of lines:  3
#
#
# name:  a7r3
# email:  arvindultimate7352@gmail.com
# number of lines:  2
#
#
# name:  Joshua de Guzman
# email:  devjoshuadeguzman@gmail.com
# number of lines:  43
#
#
# name:  Linell
# email:  tlbonnette@gmail.com
# number of lines:  14
#
#
# name:  Jérémy WALTHER
# email:  jeremy.walther@golflima.net
# number of lines:  34
#
#
# name:  Matt Hickman
# email:  mhickman@squareup.com
# number of lines:  8
#
#
# name:  Tom Ice
# email:  tomice@users.noreply.github.com
# number of lines:  13
#
#
# name:  Raimon Grau
# email:  raimonster@gmail.com
# number of lines:  7
#
#
# name:  Nicholas Skinsacos
# email:  nskins@umich.edu
# number of lines:  47
#
#
# name:  mixn
# email:  sutanovac.milos@gmail.com
# number of lines:  18
#
#
# name:  Tom Ice
# email:  contact@thomasice.com
# number of lines:  2327
#
#
# name:  Chandra Prakash
# email:  chandra.pr.158@gmail.com
# number of lines:  30
#
#
# name:  Andrew Huss
# email:  git@ahuss.com
# number of lines:  3
#
#
# name:  Laurence
# email:  liuxy6@gmail.com
# number of lines:  6
#
#
# name:  Hugo Locurcio
# email:  hugo.locurcio@hugo.pro
# number of lines:  42
#
#
# name:  Daniel
# email:  danieltaub7@gmail.com
# number of lines:  5
#
#
# name:  Andrej
# email:  andrej@gmail.com
# number of lines:  24
#
#
# name:  Miodrag Tokić
# email:  dev@loonies.io
# number of lines:  33
#
#
# name:  jdeguzman
# email:  jdeguzman@freelancer.com
# number of lines:  253
#
#
# name:  Dustin Blomquist
# email:  dustin.blomquist@gmail.com
# number of lines:  2
#
#
# name:  Joopmicroop
# email:  Joopmicroop@gmail.com
# number of lines:  38
#
#
# name:  Joopmicroop
# email:  joopmicroop@gmail.com
# number of lines:  2
#
#
# name:  Brian Kroth
# email:  bpkroth@gmail.com
# number of lines:  27

# %%
new_dict = {}
new_dict['author'] = name
new_dict['email'] = email
new_dict['lines_changed'] = c_lines
new_dict
# Out:
# {'author': ['Melih Değiş',
#   'Phạm Ngọc Thắng',
#   'Lukas Mestan',
#   'Alef Farah',
#   'Kevin Kuehler',
#   'Lukas Mestan',
#   'motiprajapati',
#   'Robert Beilich',
#   'Dan Kalowsky',
#   'Jorge Maldonado Ventura',
#   'Jess',
#   'Ben Boeckel',
#   'a7r3',
#   'Joshua de Guzman',
#   'Linell',
#   'Jérémy WALTHER',
#   'Matt Hickman',
#   'Tom Ice',
#   'Raimon Grau',
#   'Nicholas Skinsacos',
#   'mixn',
#   'Tom Ice',
#   'Chandra Prakash',
#   'Andrew Huss',
#   'Laurence',
#   'Hugo Locurcio',
#   'Daniel',
#   'Andrej',
#   'Miodrag Tokić',
#   'jdeguzman',
#   'Dustin Blomquist',
#   'Joopmicroop',
#   'Joopmicroop',
#   'Brian Kroth'],
#  'email': ['melihdegis@gmail.com',
#   'thangdc94@gmail.com',
#   'lukas.mestan@hyperia.sk',
#   'afarah@nelogica.com.br',
#   'keur@ocf.berkeley.edu',
#   'lukas.mestan@gmail.com',
#   'prajapati.moti@gmail.com',
#   'robert@beilich.de',
#   'dank@deadmime.org',
#   'jorgesumle@freakspot.net',
#   'jessachandler@gmail.com',
#   'mathstuf@gmail.com',
#   'arvindultimate7352@gmail.com',
#   'devjoshuadeguzman@gmail.com',
#   'tlbonnette@gmail.com',
#   'jeremy.walther@golflima.net',
#   'mhickman@squareup.com',
#   'tomice@users.noreply.github.com',
#   'raimonster@gmail.com',
#   'nskins@umich.edu',
#   'sutanovac.milos@gmail.com',
#   'contact@thomasice.com',
#   'chandra.pr.158@gmail.com',
#   'git@ahuss.com',
#   'liuxy6@gmail.com',
#   'hugo.locurcio@hugo.pro',
#   'danieltaub7@gmail.com',
#   'andrej@gmail.com',
#   'dev@loonies.io',
#   'jdeguzman@freelancer.com',
#   'dustin.blomquist@gmail.com',
#   'Joopmicroop@gmail.com',
#   'joopmicroop@gmail.com',
#   'bpkroth@gmail.com'],
#  'lines_changed': ['16',
#   '3',
#   '139',
#   '2',
#   '15',
#   '3136',
#   '2',
#   '6',
#   '2',
#   '6',
#   '32',
#   '3',
#   '2',
#   '43',
#   '14',
#   '34',
#   '8',
#   '13',
#   '7',
#   '47',
#   '18',
#   '2327',
#   '30',
#   '3',
#   '6',
#   '42',
#   '5',
#   '24',
#   '33',
#   '253',
#   '2',
#   '38',
#   '2',
#   '27']}

# %%
import pandas as pd
df = pd.DataFrame.from_dict(new_dict)
df
# Out:
#                      author                            email lines_changed
# 0               Melih Değiş             melihdegis@gmail.com            16
# 1           Phạm Ngọc Thắng              thangdc94@gmail.com             3
# 2              Lukas Mestan          lukas.mestan@hyperia.sk           139
# 3                Alef Farah           afarah@nelogica.com.br             2
# 4             Kevin Kuehler            keur@ocf.berkeley.edu            15
# 5              Lukas Mestan           lukas.mestan@gmail.com          3136
# 6             motiprajapati         prajapati.moti@gmail.com             2
# 7            Robert Beilich                robert@beilich.de             6
# 8              Dan Kalowsky                dank@deadmime.org             2
# 9   Jorge Maldonado Ventura         jorgesumle@freakspot.net             6
# 10                     Jess          jessachandler@gmail.com            32
# 11              Ben Boeckel               mathstuf@gmail.com             3
# 12                     a7r3     arvindultimate7352@gmail.com             2
# 13         Joshua de Guzman      devjoshuadeguzman@gmail.com            43
# 14                   Linell             tlbonnette@gmail.com            14
# 15           Jérémy WALTHER      jeremy.walther@golflima.net            34
# 16             Matt Hickman            mhickman@squareup.com             8
# 17                  Tom Ice  tomice@users.noreply.github.com            13
# 18              Raimon Grau             raimonster@gmail.com             7
# 19       Nicholas Skinsacos                 nskins@umich.edu            47
# 20                     mixn        sutanovac.milos@gmail.com            18
# 21                  Tom Ice            contact@thomasice.com          2327
# 22          Chandra Prakash         chandra.pr.158@gmail.com            30
# 23              Andrew Huss                    git@ahuss.com             3
# 24                 Laurence                 liuxy6@gmail.com             6
# 25            Hugo Locurcio           hugo.locurcio@hugo.pro            42
# 26                   Daniel            danieltaub7@gmail.com             5
# 27                   Andrej                 andrej@gmail.com            24
# 28            Miodrag Tokić                   dev@loonies.io            33
# 29                jdeguzman         jdeguzman@freelancer.com           253
# 30         Dustin Blomquist       dustin.blomquist@gmail.com             2
# 31              Joopmicroop            Joopmicroop@gmail.com            38
# 32              Joopmicroop            joopmicroop@gmail.com             2
# 33              Brian Kroth                bpkroth@gmail.com            27

# %%
df.to_csv("../outputs/git.csv", index=False)
